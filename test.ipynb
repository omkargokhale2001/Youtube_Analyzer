['Subscribe\U0001f9ce\n🥤Gfuel(affiliate): http...  PT14M56S
# 17     13260  ['Subscribe\U0001f9ce\n🥤Gfuel(affiliate): http...  PT20M10S
# 18      5263  ['AD - Go to https://NordVPN.com/pewdiepie to ...   PT13M5S
# 19     14054  ['ad\n\n\U0001f9ce', 'Subscribe\U0001f9ce\n🥤Gf...   PT19M7S

# %%
def convert_to_list(tags):
    tags = tags.strip('][').split(', ')
    ans = ""
    for i in tags:
        ans = ans + i[1:-1]
    return ans

# %%
df['Hashtags'] = df['Hashtags'].apply(lambda x:convert_to_list(x))

# %%
def duration_to_time(duration):
    times = duration.split('M')
    if len(times)>=2 and times[1]!='':
        time = float(times[0][2:]) + float(times[1][:-1])/60
    else:
        time = float(times[0][2:])
    return round(time,2)

# %%
df['Duration'] = df['Duration'].apply(lambda x:duration_to_time(x))

# %%
import calendar

# %%
def day_of_week(date):
    time_ = date.split('T')
    date = time_[0]
    date = datetime.strptime(date, '%Y-%m-%d').weekday()
    return date

# %%
df['Day'] = df['Date'].apply(lambda x:day_of_week(x))

# %%
def find_time(time):
    time_ = time.split('T')
    time_fin = time_[1]
    time_fin = int(time_fin[0:2])*60 + int(time_fin[3:5])
    return time_fin

# %%
df['Time'] = df['Date'].apply(lambda x:find_time(x))

# %%
def find_day(day):
    day_list = day.split('T')
    day_fin = day_list[0]
    day_fin = (int(day_fin[5:7])-1)*30 + int(day_fin[8:10])
    return day_fin

# %%
df['Days'] = df['Date'].apply(lambda x:find_day(x))

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Text Processing

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))


def remove_stop(title,stop_words):
    new_sent = ""
    words = word_tokenize(title)
    for i in words:
        if i not in stop_words:
            new_sent = new_sent + i
            new_sent = new_sent + " "
    return new_sent

# %%
import re
def clean_tweet(text):
    text1 = re.sub(r'@[A-Za-z0-9]+','',text)
    text2 = re.sub(r'#','',text1)
    hashtags = re.findall(r'#[A-Za-z0-9]+',text)
    hashtags = [i[1:] for i in hashtags]
    text3 = re.sub(r'RT[\s]+','',text2)
    text4 = re.sub(r'https?:\/\/\S+','',text3)
    text5 = re.sub(r'http?:\/\/\S+','',text4)
    text6 = re.sub(r'\n','',text5)
    return text6

# %%
import preprocessor as p
def remove_emoticons(tweet):
    tweet = p.clean(tweet)
    return tweet

# %%
from nltk.stem import WordNetLemmatizer


def lemmatize_words(text):
    lemmatizer = WordNetLemmatizer()
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

# %%
df['Video_name'] = df['Video_name'].str.lower()
df['Video_name'] = df['Video_name'].apply(lambda x:remove_stop(x,stop_words))
df['Video_name'] = df['Video_name'].apply(lambda x:clean_tweet(x))
df['Video_name'] = df['Video_name'].apply(lambda x:remove_emoticons(x))
df['Video_name'] = df['Video_name'].apply(lambda x:lemmatize_words(x))
df['Hashtags'] = df['Hashtags'].str.lower()

# %%
df['ratio'] = (df['Likes']/df['Views'])*100

# %%
df
# Out:
#     Unnamed: 0                  Date  \
# 0            0  2021-12-26T15:43:47Z
# 1            1  2021-12-22T19:11:27Z
# 8     0   846   343   7.243222
# 9     4   852   340   8.763312
# 10    3  1035   339  10.559720
# 11    2   996   338   7.643694
# 12    1   959   337   8.867749
# 13    0  1073   336   6.638386
# 14    4   837   333   8.351699
# 15    3   968   332   9.413941
# 16    2  1111   331   9.082580
# 17    1    59   330   7.659830
# 18    5  1080   327   6.639808
# 19    4   734   326   7.727109

# %% [markdown]
# ## Vectorization and train test

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vect = TfidfVectorizer(ngram_range=[1,2]).fit(df['Video_name'].iloc[:-1])

# %%
X_train = vect.transform(df['Video_name'].iloc[:-1])

# %%
X_train_2 = df[['Duration','Day','Time','Days']].iloc[:-1]

# %%
X_train_main = pd.merge(pd.DataFrame(X_train.toarray()), X_train_2, left_index=True, right_index=True)

# %%
y_train= df['Views'].iloc[:-1]

# %%
X_test_fin = pd.DataFrame({'Duration':[12.30],'Day':[5],'Time':[1430],'Days':[334]})
x = ["protective brother spy sister"]
x = vect.transform(x)
X_test_1 = pd.DataFrame(x.toarray())
X_test_2 = X_test_fin
X_test_final = pd.merge(X_test_1, X_test_2, left_index=True, right_index=True)

# %% [markdown]
# ### Linear Regression

# %%
reg = LinearRegression().fit(X_train,y_train)

# %%
import numpy as np

# %%
reg2 = LinearRegression().fit(X_train_2,y_train)

# %%
# !pip install mlxtend

# %%
from mlxtend.regressor import StackingRegressor
lr = LinearRegression()
sclf = StackingRegressor(regressors=[reg, reg2], 
                      meta_regressor=lr)

# %%
sclf.fit(X_train_main,y_train)
# Out:
# StackingRegressor(meta_regressor=LinearRegression(),
#                   regressors=[LinearRegression(), LinearRegression()])

# %%
sclf.predict(X_test_final)
# Out:
# array([2457413.62398941])

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg_tree_1 = DecisionTreeRegressor().fit(X_train,y_train)

# %%
reg_tree_2 = DecisionTreeRegressor().fit(X_train_2,y_train)

# %%
d_reg = DecisionTreeRegressor()
d_tree_reg = StackingRegressor(regressors=[reg_tree_1, reg_tree_2], 
                      meta_regressor=d_reg)

# %%
d_tree_reg.fit(X_train_main,y_train)
# Out:
# StackingRegressor(meta_regressor=DecisionTreeRegressor(),
#                   regressors=[DecisionTreeRegressor(), DecisionTreeRegressor()])

# %%
d_tree_reg.predict(X_test_final)
# Out:
# array([2750518.])

# %% [markdown]
# ## Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
reg_svr_1 = SVR().fit(X_train,y_train)

# %%
reg_svr_2 = SVR().fit(X_train_2,y_train)

# %%
reg_svr = SVR()
svr_reg = StackingRegressor(regressors=[reg_svr_1, reg_svr_2], 
                      meta_regressor=reg_svr)

# %%
svr_reg.fit(X_train_main,y_train)
# Out:
# StackingRegressor(meta_regressor=SVR(), regressors=[SVR(), SVR()])

# %%
svr_reg.predict(X_test_final)
# Out:
# array([2705303.9060248])

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg_1 = Lasso().fit(X_train,y_train)

# %%
lasso_reg_2 = Lasso().fit(X_train_2,y_train)

# %%
reg_lasso = Lasso()
reg_lasso_fin = StackingRegressor(regressors=[lasso_reg_1, lasso_reg_2], 
                      meta_regressor=reg_lasso)

# %%
reg_lasso_fin.fit(X_train_main,y_train)
# Out:
# StackingRegressor(meta_regressor=Lasso(), regressors=[Lasso(), Lasso()])

# %%
reg_lasso_fin.predict(X_test_final)
# Out:
# array([3017709.47085491])

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg_1 = RandomForestRegressor().fit(X_train,y_train)

# %%
rf_reg_2 = RandomForestRegressor().fit(X_train_2,y_train)

# %%
reg_rf = RandomForestRegressor()
reg_rf_fin = StackingRegressor(regressors=[rf_reg_1, rf_reg_2], 
                      meta_regressor=reg_rf)

# %%
reg_rf_fin.fit(X_train_main,y_train)
# Out:
# StackingRegressor(meta_regressor=RandomForestRegressor(),
#                   regressors=[RandomForestRegressor(), RandomForestRegressor()])

# %%
reg_rf_fin.predict(X_test_final)
# Out:
# array([2658607.26])

# %% [markdown]
# ## Finding Best Video Names and other parameters

# %%
df
# Out:
#     Unnamed: 0                  Date  \
# 0            0  2021-12-26T15:43:47Z
# 1            1  2021-12-22T19:11:27Z
# 2            2  2021-12-20T14:01:11Z
# 3            3  2021-12-20T15:59:32Z
# 4            4  2021-12-17T15:16:43Z
# 5            5  2021-12-16T16:47:49Z
# 6            6  2021-12-15T17:35:00Z
# 7            7  2021-12-14T16:00:15Z
# 8            8  2021-12-13T14:06:47Z
# 9            9  2021-12-10T14:12:39Z
# 10          10  2021-12-09T17:15:47Z
# 11          11  2021-12-08T16:36:50Z
# 12          12  2021-12-07T15:59:19Z
# 13          13  2021-12-06T17:53:40Z
# 14          14  2021-12-03T13:57:16Z
# 15          15  2021-12-02T16:08:04Z
# 16          16  2021-12-01T18:31:37Z
# 17          17  2021-11-30T00:59:03Z
# 18          18  2021-11-27T18:00:44Z
# 19          19  2021-11-26T12:14:45Z
#
#                                            Video_name    Views   Likes  \
# 0                     spiderman fan please explain ..  1491856  128992
# 1                       next gen graphic kinda nut ..  2678694  168091
# 2   laugh win billion $ $ $ ( maybe , impossible w...  3135226  248601
# 3   five night freddy 's security breach gameplay ...  2058838  137306
# 4              found new forbidden minecraft block ..  2241987  165961
# 5                                 nft hit new low ...  2409866  178618
# 6                             gary vee wee bit cringe  1944015  127706
# 7                      fell new minecraft lush cave !  3289589  235803
# 8                       bad design deserves go jail .  3678446  266438
# 9   figured atom existed thousand year ago still d...  2046749  179363
# 10                youtube copyright seriously piss ..  2751664  290568
# 11                             new minecraft update !  4507271  344522
# 12                                       hate mukbang  5027894  445861
# 13                   rating/reacting reaction channel  2750518  182590
# 14                                        's ? zamn !  2499168  208723
# 15                                                  .  3068428  288860
# 16                                   addressing hater  3259305  296029
# 17                      ... 're supposed eat pizza ..  2621938  200836
# 18                     reacting worst plastic surgery  2705304  179627
# 19                         mr beast squid game review  6918978  534637
#
#     Comments                                           Hashtags  Duration  \
# 0       4128  ad\n\nnew tsuki has launched 👘: https://bit.ly...     10.50
# 1       6323  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     11.45
# 2       5265  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     10.23
# 3       4842  ad - get my new g fuel pewdiepie snö shaker!!:...     19.48
# 4       5810  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     13.42
# 5       6933  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      8.33
# 6       6786  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     17.17
# 7       7494  ad - get the ghost pewdiepie tambourine combo👊...     16.93
# 8       5198  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     10.05
# 9       8609  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     11.98
# 10     12490  ad - holiday deal! go to https://nordvpn.com/p...      8.87
# 11     14044  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     16.55
# 12     16278  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      9.92
# 13      6987  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     20.63
# 14      7762  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      8.35
# 15     12085  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      8.83
# 16     10415  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     14.93
# 17     13260  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     20.17
# 18      5263  ad - go to https://nordvpn.com/pewdiepie to ge...     13.08
# 19     14054  ad\n\n\u0001f9cesubscribe\u0001f9ce\n🥤gfuel(af...     19.12
#
#     Day  Time  Days      ratio
# 0     6   943   356   8.646411
# 1     2  1151   352   6.275110
# 2     0   841   350   7.929285
# 3     0   959   350   6.669102
# 4     4   916   347   7.402407
# 5     3  1007   346   7.411947
# 6     2  1055   345   6.569188
# 7     1   960   344   7.168160
# 8     0   846   343   7.243222
# 9     4   852   340   8.763312
# 10    3  1035   339  10.559720
# 11    2   996   338   7.643694
# 12    1   959   337   8.867749
# 13    0  1073   336   6.638386
# 14    4   837   333   8.351699
# 15    3   968   332   9.413941
# 16    2  1111   331   9.082580
# 17    1    59   330   7.659830
# 18    5  1080   327   6.639808
# 19    4   734   326   7.727109

# %%
df = df.sort_values(by = 'Views')

# %%
df
# Out:
#     Unnamed: 0                  Date  \
# 0            0  2021-12-26T15:43:47Z
# 6            6  2021-12-15T17:35:00Z
# 9            9  2021-12-10T14:12:39Z
# 3            3  2021-12-20T15:59:32Z
# 4            4  2021-12-17T15:16:43Z
# 5            5  2021-12-16T16:47:49Z
# 14          14  2021-12-03T13:57:16Z
# 17          17  2021-11-30T00:59:03Z
# 1            1  2021-12-22T19:11:27Z
# 18          18  2021-11-27T18:00:44Z
# 13          13  2021-12-06T17:53:40Z
# 10          10  2021-12-09T17:15:47Z
# 15          15  2021-12-02T16:08:04Z
# 2            2  2021-12-20T14:01:11Z
# 16          16  2021-12-01T18:31:37Z
# 7            7  2021-12-14T16:00:15Z
# 8            8  2021-12-13T14:06:47Z
# 11          11  2021-12-08T16:36:50Z
# 12          12  2021-12-07T15:59:19Z
# 19          19  2021-11-26T12:14:45Z
#
#                                            Video_name    Views   Likes  \
# 0                     spiderman fan please explain ..  1491856  128992
# 6                             gary vee wee bit cringe  1944015  127706
# 9   figured atom existed thousand year ago still d...  2046749  179363
# 3   five night freddy 's security breach gameplay ...  2058838  137306
# 4              found new forbidden minecraft block ..  2241987  165961
# 5                                 nft hit new low ...  2409866  178618
# 14                                        's ? zamn !  2499168  208723
# 17                      ... 're supposed eat pizza ..  2621938  200836
# 1                       next gen graphic kinda nut ..  2678694  168091
# 18                     reacting worst plastic surgery  2705304  179627
# 13                   rating/reacting reaction channel  2750518  182590
# 10                youtube copyright seriously piss ..  2751664  290568
# 15                                                  .  3068428  288860
# 2   laugh win billion $ $ $ ( maybe , impossible w...  3135226  248601
# 16                                   addressing hater  3259305  296029
# 7                      fell new minecraft lush cave !  3289589  235803
# 8                       bad design deserves go jail .  3678446  266438
# 11                             new minecraft update !  4507271  344522
# 12                                       hate mukbang  5027894  445861
# 19                         mr beast squid game review  6918978  534637
#
#     Comments                                           Hashtags  Duration  \
# 0       4128  ad\n\nnew tsuki has launched 👘: https://bit.ly...     10.50
# 6       6786  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     17.17
# 9       8609  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     11.98
# 3       4842  ad - get my new g fuel pewdiepie snö shaker!!:...     19.48
# 4       5810  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     13.42
# 5       6933  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      8.33
# 14      7762  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      8.35
# 17     13260  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     20.17
# 1       6323  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     11.45
# 18      5263  ad - go to https://nordvpn.com/pewdiepie to ge...     13.08
# 13      6987  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     20.63
# 10     12490  ad - holiday deal! go to https://nordvpn.com/p...      8.87
# 15     12085  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      8.83
# 2       5265  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     10.23
# 16     10415  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     14.93
# 7       7494  ad - get the ghost pewdiepie tambourine combo👊...     16.93
# 8       5198  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     10.05
# 11     14044  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...     16.55
# 12     16278  subscribe\u0001f9ce\n🥤gfuel(affiliate): https:...      9.92
# 19     14054  ad\n\n\u0001f9cesubscribe\u0001f9ce\n🥤gfuel(af...     19.12
#
#     Day  Time  Days      ratio
# 0     6   943   356   8.646411
# 6     2  1055   345   6.569188
# 9     4   852   340   8.763312
# 3     0   959   350   6.669102
# 4     4   916   347   7.402407
# 5     3  1007   346   7.411947
# 14    4   837   333   8.351699
# 17    1    59   330   7.659830
# 1     2  1151   352   6.275110
# 18    5  1080   327   6.639808
# 13    0  1073   336   6.638386
# 10    3  1035   339  10.559720
# 15    3   968   332   9.413941
# 2     0   841   350   7.929285
# 16    2  1111   331   9.082580
# 7     1   960   344   7.168160
# 8     0   846   343   7.243222
# 11    2   996   338   7.643694
# 12    1   959   337   8.867749
# 19    4   734   326   7.727109

# %%
import nltk

# %%
from nltk.tag import pos_tag


def get_optimal_params(df):
    words_imp = []
    df_sorted = df.sort_values(by='Views')
    lst_names = list(df['Video_name'])[15:]
    for i in range(len(lst_names)):
        tagged_sent = pos_tag(lst_names[i].split())
        for word in tagged_sent:
            if word[1]=='NN':
                words_imp.append(word[0])
    duration = list(df_sorted['Duration'])[15:]
    duration = [int(x) for x in duration]
    return words_imp,round((sum(duration)/len(duration)),2)

# %%
get_optimal_params(df)
# Out:
# (['minecraft',
#   'lush',
#   'cave',
#   'design',
#   'jail',
#   'minecraft',
#   'update',
#   'hate',
#   'mukbang',
#   'mr',
#   'beast',
#   'game',
#   'review'],
#  14.0)

# %%
string_ = 'PT14S'
ans = string_.split('M')
ans
# Out:
# ['PT14S']
